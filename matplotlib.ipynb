# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x= np.linspace(0,10 , 200)

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel(" this is my x label data ")
plt.ylabel(" this is my y label data ")
plt.title(" this is my tiltle ")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)

# %%
x
# Out:
# array([0.04094567, 0.49552994, 0.45542277, 0.81266244, 0.0444385 ,
#        0.95185565, 0.87110391, 0.78176295, 0.08984449, 0.70397157,
#        0.91897793, 0.14610414, 0.9761422 , 0.59792093, 0.43144962,
#        0.17403185, 0.99302215, 0.24239044, 0.72868728, 0.52618072,
#        0.25406097, 0.49951203, 0.86618667, 0.37009134, 0.01246137,
#        0.56569222, 0.61895068, 0.52838124, 0.91711473, 0.6550891 ,
#        0.58332247, 0.72452669, 0.1521638 , 0.58444407, 0.30381498,
#        0.34674717, 0.64702038, 0.14781645, 0.01615157, 0.56035194,
#        0.66050323, 0.8875997 , 0.87212672, 0.76008417, 0.46200189,
#        0.69574154, 0.19226586, 0.33678274, 0.37923545, 0.63213683])

# %%
y
# Out:
# array([0.29372869, 0.70789259, 0.98990756, 0.22670418, 0.67477373,
#        0.82527326, 0.13082302, 0.54938618, 0.4983258 , 0.49433077,
#        0.31549807, 0.19432026, 0.65183028, 0.55221891, 0.14782686,
#        0.1817545 , 0.86694477, 0.87176535, 0.34031361, 0.8273923 ,
#        0.32272002, 0.67234479, 0.19901084, 0.71915537, 0.56326375,
#        0.06116974, 0.83483336, 0.79709074, 0.44327623, 0.57954462,
#        0.75635577, 0.35497043, 0.32893313, 0.36454428, 0.93124715,
#        0.14840096, 0.03225508, 0.64678379, 0.63883438, 0.64792725,
#        0.00303617, 0.63501504, 0.17513302, 0.95413737, 0.08177992,
#        0.86933264, 0.5637163 , 0.59762602, 0.60020079, 0.00788332])

# %%
colours = np.random.rand(50)
sizes = 1000*np.random.rand(50)
plt.scatter(x,y , c = colours , s = sizes , alpha = .1)
plt.xlabel(" x aixs ")
plt.ylabel(" y axis ")
plt.title("my title random data")
# Out:
# Text(0.5, 1.0, 'my title random data')

# %%
x = ['a' ,'b','c','d','e']

# %%
y = np.random.rand(5)
plt.bar(x,y)
plt.xlabel(" x axis")
plt.ylabel("y label")
plt.title(" my data")
# Out:
# Text(0.5, 1.0, ' my data')

# %%
y
# Out:
# array([0.99185378, 0.9256767 , 0.65015296, 0.20981851, 0.47517707])

# %%
plt.barh(x,y)

plt.xlabel(" x axis")
plt.ylabel("y label")
plt.title(" my data")
# Out:
# Text(0.5, 1.0, ' my data')

# %%
plt.plot(x,y , '--b')
plt.figure(figsize=(6,2))
plt.xlabel(" this is my x label data ")
plt.ylabel(" this is my y label data ")
plt.title(" this is my tiltle ")
plt.show()
plt.grid()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colours = np.random.rand(50)
sizes = 1000*np.random.rand(50)
plt.scatter(x,y , c = '#00FFFF' , s = sizes , alpha = .5 , marker = 'v')
plt.xlabel(" x aixs ")
plt.ylabel(" y axis ")
plt.title("my title random data")
# Out:
# Text(0.5, 1.0, 'my title random data')

# %%
x = [4,5,6,7,8,9]
y = [6,7,8,9,10,11]
plt.plot(x,y)
plt.show()

# %%
x = [4,52,67,7,88,9]
y = [6,7,85,47,90,11]
plt.plot(x,y)
plt.show()

# %%
x = [4,52,67,7,88,9]
y = [6,7,85,47,90,11]
plt.scatter(x,y)
plt.show()

# %%
data = [1,2,3,4,5,1,2,3,4,6,4,7,8,1,2,3]

# %%
plt.hist(data)
plt.show()

# %%
x = [4,52,67,7,88,9]
y = [6,7,85,47,90,11]
colour = ['red' , 'blue' , '#00008B' , 'green' , 'pink' , 'black']
plt.scatter(x,y , c = colour)
plt.show()

# %%
x = np.random.randn(50)
y = np.random.randn(50)
z = np.random.randn(50)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 8
#       6 ax = fig.add_subplot(projection = '3d')
#       7 ax.scatter(x,y,z)
# ----> 8 ax.show()
#
# AttributeError: 'Axes3DSubplot' object has no attribute 'show'
